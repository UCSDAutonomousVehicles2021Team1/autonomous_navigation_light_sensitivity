# %%
# import the necessary packages
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
imageA = cv2.imread('default.jpg')
imageB = cv2.imread('data_lamp_default.jpg')
imageC = cv2.imread('config-1.jpg')
imageD = cv2.imread('config-2.jpg')
imageE = cv2.imread('config-3.jpg')
imageF = cv2.imread('config-4.jpg')
imageG = cv2.imread('config-5.jpg')

# %%
def calculate_mse(imageA, imageB):
    # the 'Mean Squared Error' between the two images is the
    # sum of the squared difference between the two images;
    # NOTE: Two images have the same dimension
    error = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    error /= float(imageA.shape[0] * imageA.shape[1])
    
    # return the MSE, the lower the error, the more "similar" the two images are
    return error

# %%
ssim(imageA, imageB, multichannel=True)
# Out:
# 0.5678964146584841

# %%
ssim(imageA, imageC, multichannel=True)
# Out:
# 0.4074575654563099

# %%
ssim(imageA, imageD, multichannel=True)
# Out:
# 0.3363396512949504

# %%
ssim(imageA, imageE, multichannel=True)
# Out:
# 0.5358111122556751

# %%
ssim(imageA, imageF, multichannel=True)
# Out:
# 0.4040941499537271

# %%
ssim(imageA, imageG, multichannel=True)
# Out:
# 0.26160799089648756

# %%
def compare_images(imageA, imageB):
    # compute the mean squared error and structural similarity
    # index for the images
    m = calculate_mse(imageA, imageB)
    s = ssim(imageA, imageB, multichannel=True)
    # setup the figure
    fig = plt.figure()
    plt.suptitle("SSIM: %.3f, MSE: %.2f" % (s, m))
    # show first image
    ax = fig.add_subplot(1, 2, 1)
    plt.imshow(imageA, cmap = plt.cm.gray)
    plt.axis("off")
    # show the second image
    ax = fig.add_subplot(1, 2, 2)
    plt.imshow(imageB, cmap = plt.cm.gray)
    plt.axis("off")
    # show the images
    plt.show()

# %%
compare_images(imageA, imageB)

# %%
compare_images(imageA, imageC)

# %%
compare_images(imageA, imageD)

# %%
compare_images(imageA, imageE)

# %%
compare_images(imageA, imageF)

# %%
compare_images(imageA, imageG)
